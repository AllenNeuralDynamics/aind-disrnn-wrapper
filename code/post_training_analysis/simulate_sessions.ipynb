# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import glob
import pickle
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['svg.fonttype'] = 'none'
import seaborn as sns

from aind_behavior_gym.dynamic_foraging.task import CoupledBlockTask, UncoupledBlockTask
from aind_dynamic_foraging_models.generative_model import ForagerCollection

# %%
# load saved df for model fitting results
df_model_fitting_relevant = pd.read_pickle(
    os.path.expanduser("~/capsule/analysis_result/df_model_fitting_relevant_250714.pkl")
)

# %%
df_model_fitting_relevant.columns

# %%
df_model_fitting_relevant.curriculum_name.value_counts()

# %%
df_model_fitting_relevant.current_stage_actual.value_counts()

# %% [markdown]
# # simulate sessions with fitted parameters

# %%
# # run and saved on 250716
# # takes quite long, ~25min

# # generate simulated data for each model and task type

# model_types = [
#     'ForagingCompareThreshold', 'QLearning_L2F1_softmax', 'QLearning_L1F1_CK1_softmax'
# ]
# model_aliases = {
#     'ForagingCompareThreshold': 'CompareToThreshold',
#     'QLearning_L2F1_softmax': 'Hattori2019',
#     'QLearning_L1F1_CK1_softmax': 'Bari2019'
# }

# task_types = [
#     'Uncoupled Baiting', 'Uncoupled Without Baiting', 'Coupled Baiting', 'None'
# ]

# later_stages = [
#     'STAGE_FINAL', 'GRADUATED'
# ]


# dict_simulation_results = {}
# for model_type in model_types:
#     for task_type in task_types:

#         # create an empty DataFrame to store results
#         print(f"Processing Model: {model_type}, Task: {task_type}")
#         columns_results = [
#             'subject_id', 'session_date', 'agent_alias', 'curriculum_name', 
#             'params', 'n_trials', 'random_seed',
#             'choice_history', 'reward_history'
#         ]
#         df_results = pd.DataFrame(columns=columns_results)


#         df_model_task = df_model_fitting_relevant[
#             (df_model_fitting_relevant.agent_alias == model_type) &
#             (df_model_fitting_relevant.curriculum_name == task_type)
#         ]
#         # iterate over subject_ids
#         for subject_id in df_model_task.subject_id.unique():
#             df_model_task_subject = df_model_task[df_model_task.subject_id == subject_id]
#             if len(df_model_task_subject) > 0:
#                 print(f" Subject-{subject_id}: {len(df_model_task_subject)} sessions")

#                 # bootstrap sampling from later sessions
#                 if len(df_model_task_subject[df_model_task_subject['current_stage_actual'].isin(later_stages)]) >= 0.5*len(df_model_task_subject):
#                     print("  bootstrap sampling from later stages")
#                     df_model_task_subject_later = df_model_task_subject[df_model_task_subject.current_stage_actual.isin(later_stages)]
#                 else:
#                     print("  bootstrap sampling based on session_date")
#                     # df is sorted, choose last 50% of sessions
#                     df_model_task_subject_later = df_model_task_subject.iloc[len(df_model_task_subject)//2:]
                
#                 # bootstrap sampling
#                 df_model_task_subject_later = df_model_task_subject_later.sample(
#                     frac=1.6, replace=True
#                 )
#                 # generate random seeds for each sampled row
#                 random_seeds = np.random.randint(0, 10000, size=len(df_model_task_subject_later))

#                 print(f"   n_sessions to simulate: {len(df_model_task_subject_later)}")
#                 # iterate over the sampled rows
#                 for seed, (_, row) in zip(random_seeds, df_model_task_subject_later.iterrows()):

#                     fitted_params = row['params']
#                     n_trials = row['n_trials']
                    
#                     # create task
#                     if row['curriculum_name'] == 'Uncoupled Baiting':
#                         task = UncoupledBlockTask(reward_baiting=True, num_trials=n_trials, seed=seed)
#                     elif row['curriculum_name'] == 'Uncoupled Without Baiting':
#                         task = UncoupledBlockTask(reward_baiting=False, num_trials=n_trials, seed=seed)
#                     elif row['curriculum_name'] == 'Coupled Baiting':
#                         task = CoupledBlockTask(reward_baiting=True, num_trials=n_trials, seed=seed)
#                     elif row['curriculum_name'] == 'None':
#                         # use a default task of uncoupled baiting for 'None' curriculum
#                         task = UncoupledBlockTask(reward_baiting=True, num_trials=n_trials, seed=seed)
#                     else:
#                         continue

#                     # create forager
#                     forager = ForagerCollection().get_preset_forager(model_aliases[model_type], seed=seed)
#                     forager.set_params(**fitted_params)

#                     # simulate task
#                     forager.perform(task)
#                     choice_history = forager.get_choice_history()
#                     reward_history = forager.get_reward_history()

#                     # create a new row for the results DataFrame
#                     new_row = {
#                         'subject_id': subject_id,
#                         'session_date': row['session_date'],
#                         'agent_alias': model_type,
#                         'curriculum_name': task_type,
#                         'params': fitted_params,
#                         'n_trials': n_trials,
#                         'random_seed': seed,
#                         'choice_history': choice_history,
#                         'reward_history': reward_history
#                     }
#                     # append the new row to the results DataFrame
#                     df_results.loc[len(df_results)] = new_row
        
#         # store the results in the dictionary
#         dict_simulation_results[(model_type, task_type)] = df_results

# %%
# # save the results to a pickle file
# output_file = os.path.expanduser("~/capsule/analysis_result/dict_simulation_results_250716.pkl")
# with open(output_file, 'wb') as f:
#     pickle.dump(dict_simulation_results, f)

# %%
# load saved simulation results
saved_file = os.path.expanduser("~/capsule/analysis_result/dict_simulation_results_250716.pkl")
with open(saved_file, 'rb') as f:
    dict_simulation_results = pickle.load(f)
